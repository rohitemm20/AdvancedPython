# %%
#FUCTION THAT TAKES 2 ARGUMENTS
def describe_pet(animal_type, pet_name):

    print(f"I have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name}.\n")

# Positional arguments where order matters
describe_pet('cat', 'albert')

# Keyword arguments where order does not matter
describe_pet(animal_type='komodo dragon', pet_name='sinclair')
# Out:
# I have a cat.
# My cat's name is albert.
#
# I have a komodo dragon.
# My komodo dragon's name is sinclair.

# %%
# Calling the same function multiple times
describe_pet('cake', 'nono')
describe_pet('parrot', 'sonu')
describe_pet('cosmic being', 'unopa')
# Out:
# I have a cake.
# My cake's name is nono.
#
# I have a parrot.
# My parrot's name is sonu.
#
# I have a cosmic being.
# My cosmic being's name is unopa.

# %%
# Correct order
describe_pet('cat', 'sinclair')

# Wrong order
describe_pet('kobo', 'dog')
# Out:
# I have a cat.
# My cat's name is sinclair.
#
# I have a kobo.
# My kobo's name is dog.

# %%
# Keyword arguments allow any order
describe_pet(pet_name='bro', animal_type='dog')
describe_pet(animal_type='snake', pet_name='oscar')
# Out:
# I have a dog.
# My dog's name is bro.
#
# I have a snake.
# My snake's name is oscar.

# %%
def describe_pet(animal_type, pet_name='cat'):

    print(f"I have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name}.\n")

# Using default value
describe_pet('omni')

# Overriding default value
describe_pet('pero', 'macaw')
describe_pet('nokia', 'koala')
# Out:
# I have a omni.
# My omni's name is dog.
#
# I have a pero.
# My pero's name is macaw.
#
# I have a nokia.
# My nokia's name is koala.

# %%
# Positional argument for pet_name only
describe_pet('Kala')  
# Kala → pet_name, animal_type uses default 'dog'

# Keyword argument for pet_name
describe_pet(pet_name='Kala')  

# Two positional arguments
describe_pet('Bhairav', 'cat')  

# Two keyword arguments
describe_pet(pet_name='Shero', animal_type='parrot')  

# Two keyword arguments (order swapped)
describe_pet(animal_type='hamster', pet_name='Kala')
# Out:
# I have a dog.
# My dog's name is Kala.
#
# I have a dog.
# My dog's name is Kala.
#
# I have a cat.
# My cat's name is Bhairav.
#
# I have a parrot.
# My parrot's name is Shero.
#
# I have a hamster.
# My hamster's name is Kala.

# %%
def get_formatted_pet_name(pet_name):
    """Return the pet's name in title case."""
    return pet_name.title()

print(get_formatted_pet_name('omni'))
print(get_formatted_pet_name('maroon'))
# Out:
# Omni
# Maroon

# %%
def build_pet_profile(name, animal_type):
    """Return a dictionary about a pet."""
    return {'name': name, 'animal_type': animal_type}

pet = build_pet_profile('Kala', 'dog')
print(build_pet_profile('ignis', 'cat'))
print(pet)
# Out:
# {'name': 'ignis', 'animal_type': 'cat'}
# {'name': 'Kala', 'animal_type': 'dog'}

# %%
def greet_pets(pet_names):
    """Greet each pet in the list."""
    for name in pet_names:
        print(f"Hiiii, {name.title()}!")

pets = ['sinclair', 'mononoke', 'petrina']
greet_pets(pets)
# Out:
# Hiiii, Sinclair!
# Hiiii, Mononoke!
# Hiiii, Petrina!

# %%
def uppercase_pets(pet_names):
    """Modify list elements to uppercase."""
    for i in range(len(pet_names)):
        pet_names[i] = pet_names[i].upper()

uppercase_pets(pets)
print(pets)
# Out:
# ['SINCLAIR', 'MONONOKE', 'PETRINA']

# %%
pets = ['mephisto','cleopatra','napolean']
new_list = uppercase_pets_copy(pets[:])
print("Original:", pets)
print("Modified:", new_list)
# Out:
# Original: ['mephisto', 'cleopatra', 'napolean']
# Modified: ['MEPHISTO', 'CLEOPATRA', 'NAPOLEAN']

# %%
def list_pets(*pets):
    """
    Accepts any number of pet names.
    *pets collects all arguments into a tuple.
    """
    print("My pets are:")
    for pet in pets:  # Loop through each pet name
        print(f"- {pet}")

# Passing one argument
list_pets('kuro')

# Passing multiple arguments
list_pets('Kamp', 'BMO', 'DON')
# Out:
# My pets are:
# - kuro
# My pets are:
# - Kamp
# - BMO
# - DON

# %%
def show_pet_info(owner, *pets):
    """
    First argument is owner name (positional),
    remaining arguments are pet names (*pets).
    """
    print(f"Owner: {owner}")
    print("Pets:")
    for pet in pets:  # Loop through each pet name
        print(f"- {pet}")

# First argument is owner, rest are pets
show_pet_info('Don','don2','dondondon')
# Out:
# Owner: Don
# Pets:
# - don2
# - dondondon

# %%
def build_pet_profile(name, **info):
    """
    Accepts arbitrary keyword arguments.
    **info stores them as a dictionary.
    """
    info['name'] = name  # Add the pet name to the dictionary
    return info

# Passing extra details as keyword arguments
pet = build_pet_profile('opium', animal_type='crocodile', age=67, color='green')
print(pet)  # Output will be a dictionary with all details
# Out:
# {'animal_type': 'crocodile', 'age': 67, 'color': 'green', 'name': 'opium'}
