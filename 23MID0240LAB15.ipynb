# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline

# %%
#WORKING WITH IMAGES USING matplotlib

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
img = np.asarray(Image.open('/home/matlab/Downloads/bug.jpg'))
print(repr(img))
# Out:
# array([[[ 22,  54,  33],
#         [ 23,  55,  34],
#         [ 21,  52,  34],
#         ...,
#         [ 15,  24,  21],
#         [ 13,  22,  19],
#         [ 11,  20,  17]],
#
#        [[ 27,  59,  38],
#         [ 28,  60,  39],
#         [ 24,  55,  37],
#         ...,
#         [ 17,  26,  23],
#         [ 16,  25,  22],
#         [ 16,  25,  22]],
#
#        [[ 20,  52,  31],
#         [ 24,  56,  35],
#         [ 24,  55,  37],
#         ...,
#         [ 17,  26,  23],
#         [ 18,  27,  24],
#         [ 18,  27,  24]],
#
#        ...,
#
#        [[ 15,  80,  38],
#         [ 16,  76,  38],
#         [ 18,  76,  38],
#         ...,
#         [ 30, 124,  62],
#         [ 38, 129,  50],
#         [ 69, 140,  46]],
#
#        [[ 10,  74,  39],
#         [ 12,  73,  39],
#         [ 11,  75,  40],
#         ...,
#         [ 26, 121,  63],
#         [ 44, 132,  58],
#         [ 91, 157,  69]],
#
#        [[ 12,  75,  44],
#         [ 16,  79,  48],
#         [ 14,  81,  46],
# ...

# %% [markdown]
# **Prints original image**

# %%
imgplot= plt.imshow(img)

# %%
lum_img = img[:,:,0]
plt.imshow(lum_img)

# %%
plt.imshow(lum_img, cmap="hot")

# %%
imgplot= plt.imshow(lum_img)
imgplot.set_cmap('nipy_spectral')

# %%
imgplot= plt.imshow(lum_img)
plt.colorbar()

# %%
plt.hist(lum_img.ravel(),bins=range(256),fc='k', ec='k')
# Out:
# (array([ 5533.,  1477.,  1703.,  2035.,  2484.,  3106.,  4132.,  6038.,
#         10652., 21927., 46776., 76658., 74586., 73755., 70908., 64180.,
#         54441., 45706., 38316., 32844., 28285., 24616., 21326., 18801.,
#         16565., 14980., 14210., 13088., 12733., 12433., 12170., 11530.,
#         11507., 11276., 11080., 10788., 10636., 10308., 10031., 10022.,
#          9903.,  9399.,  9446.,  9305.,  9254.,  9093.,  9108.,  9012.,
#          8853.,  8570.,  8753.,  8500.,  8287.,  8112.,  8076.,  7876.,
#          7747.,  7675.,  7336.,  7331.,  6932.,  6748.,  6321.,  6167.,
#          5774.,  5545.,  5355.,  4972.,  4788.,  4589.,  4430.,  4184.,
#          4033.,  3779.,  3630.,  3387.,  3288.,  3209.,  3042.,  2983.,
#          2926.,  2747.,  2774.,  2660.,  2684.,  2572.,  2477.,  2457.,
#          2507.,  2363.,  2375.,  2350.,  2331.,  2252.,  2236.,  2148.,
#          2139.,  2099.,  2008.,  2012.,  2036.,  1929.,  1857.,  1955.,
# ...

# %%
plt.imshow(lum_img, clim=(0,175))

# %%
imgplot= plt.imshow(lum_img)
imgplot.set_clim(0,175)

# %%
img = Image.open('/home/matlab/Downloads/bug.jpg')
img.thumbnail((64,64))
imgplot = plt.imshow(img)

# %%
img = Image.open('/home/matlab/Downloads/bug.jpg')
grayscale_image = img.convert('L')
plt.imshow(grayscale_image, cmap='gray')

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

color_image = Image.open('/home/matlab/Downloads/bug.jpg')

grayscale_image = color_image.convert('L')

grayscale_image_array = np.asarray(grayscale_image)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)  
plt.imshow(grayscale_image_array, cmap='gray')
plt.title("Grayscale Image")
plt.axis('off')


plt.subplot(1, 2, 2) 
plt.hist(grayscale_image_array.ravel(), bins=range(256), fc='k', ec='k')
plt.title('Pixel Intensity Histogram')
plt.xlabel('Pixel Intensity')
plt.ylabel('Frequency')

plt.show()
